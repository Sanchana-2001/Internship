# %%
# Import necessary libraries
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk

# %%
# Download stopwords from NLTK
nltk.download('stopwords')

# Initialize stemmer and stopwords
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# Function to preprocess the text
def preprocess_text(text):
    # Lowercasing
    text = text.lower()
    # Removing special characters and digits
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Tokenize the text and remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]
    # Stemming
    words = [stemmer.stem(word) for word in words]
    return ' '.join(words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sanchana\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Loading dataset 
df = pd.read_csv('Mortage.csv') 

# Preprocessing the 'text' column
df['cleaned_text'] = df['text'].apply(preprocess_text)

# %%
# Split data into features (X) and labels (y)
X = df['cleaned_text']  # Use the cleaned text
y = df['label']         # Column containing labels

# Vectorization using TF-IDF
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %%
# Function to train and evaluate different models
def evaluate_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Classification Report:\n{classification_report(y_test, y_pred)}')

# %%
# Naive Bayes Classifier
print("Naive Bayes Classifier:")
nb_model = MultinomialNB()
evaluate_model(nb_model, X_train, X_test, y_train, y_test)
# Out:
# Naive Bayes Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       1.00      1.00      1.00         2
#  Partnership       0.50      1.00      0.67         1
#        Trust       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.83      0.83      0.78         5
# weighted avg       0.90      0.80      0.80         5

# %%
# Support Vector Machine (SVM) Classifier
print("\nSVM Classifier:")
svm_model = SVC()
evaluate_model(svm_model, X_train, X_test, y_train, y_test)
# Out:
# SVM Classifier:
# Accuracy: 0.6
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       0.50      1.00      0.67         2
#  Partnership       1.00      1.00      1.00         1
#        Trust       0.00      0.00      0.00         2
#
#     accuracy                           0.60         5
#    macro avg       0.50      0.67      0.56         5
# weighted avg       0.40      0.60      0.47         5
# C:\Users\Sanchana\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# Logistic Regression Classifier
print("\nLogistic Regression Classifier:")
logreg_model = LogisticRegression(max_iter=1000)
evaluate_model(logreg_model, X_train, X_test, y_train, y_test)
# Out:
# Logistic Regression Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       0.67      1.00      0.80         2
#  Partnership       1.00      1.00      1.00         1
#        Trust       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.89      0.83      0.82         5
# weighted avg       0.87      0.80      0.79         5

# %%
# Random Forest Classifier
print("\nRandom Forest Classifier:")
rf_model = RandomForestClassifier(n_estimators=100)
evaluate_model(rf_model, X_train, X_test, y_train, y_test)
# Out:
# Random Forest Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       0.67      1.00      0.80         2
#  Partnership       1.00      1.00      1.00         1
#        Trust       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.89      0.83      0.82         5
# weighted avg       0.87      0.80      0.79         5

# %%
# !pip install xgboost

# %%
#importing libraries for other models
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

# %%
# Gradient Boosting Classifier
print("\nGradient Boosting Classifier:")
gbc_model = GradientBoostingClassifier(n_estimators=100)
evaluate_model(gbc_model, X_train, X_test, y_train, y_test)
# Out:
# Gradient Boosting Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       0.67      1.00      0.80         2
#  Partnership       1.00      1.00      1.00         1
#        Trust       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.89      0.83      0.82         5
# weighted avg       0.87      0.80      0.79         5

# %%
# AdaBoost Classifier
print("\nAdaBoost Classifier:")
ada_model = AdaBoostClassifier(n_estimators=100)
evaluate_model(ada_model, X_train, X_test, y_train, y_test)
# Out:
# AdaBoost Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       0.67      1.00      0.80         2
#  Partnership       1.00      1.00      1.00         1
#        Trust       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.89      0.83      0.82         5
# weighted avg       0.87      0.80      0.79         5

# %%
# Decision Tree Classifier
print("\nDecision Tree Classifier:")
dt_model = DecisionTreeClassifier()
evaluate_model(dt_model, X_train, X_test, y_train, y_test)
# Out:
# Decision Tree Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#      Mortage       0.67      1.00      0.80         2
#  Partnership       1.00      1.00      1.00         1
#        Trust       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.89      0.83      0.82         5
# weighted avg       0.87      0.80      0.79         5

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical labels to numeric values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

X_train1, X_test1, y_train1, y_test1 = train_test_split(X_tfidf, y_encoded, test_size=0.2, random_state=42)


print("\nXGBoost Classifier:")
xgb_model = xgb.XGBClassifier(n_estimators=100)
evaluate_model(xgb_model, X_train1, X_test1, y_train1, y_test1)
# Out:
# XGBoost Classifier:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      1.00      1.00         1
#            2       1.00      0.50      0.67         2
#
#     accuracy                           0.80         5
#    macro avg       0.89      0.83      0.82         5
# weighted avg       0.87      0.80      0.79         5

# %%
# K-Nearest Neighbors Classifier
import os
os.environ["OMP_NUM_THREADS"] = "1"  # Limit OpenMP to 1 thread
os.environ["MKL_NUM_THREADS"] = "1"  # If using Intel MKL

print("\nK-Nearest Neighbors Classifier:")
knn_model = KNeighborsClassifier(n_neighbors=3)  # You can adjust the number of neighbors
evaluate_model(knn_model, X_train1, X_test1, y_train1, y_test1)
# Out:
# K-Nearest Neighbors Classifier:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c155b35acf25> in <module>
#       6 print("\nK-Nearest Neighbors Classifier:")
#       7 knn_model = KNeighborsClassifier(n_neighbors=3)  # You can adjust the number of neighbors
# ----> 8 evaluate_model(knn_model, X_train1, X_test1, y_train1, y_test1)
#
# <ipython-input-5-8c126c6c5717> in evaluate_model(model, X_train, X_test, y_train, y_test)
#       2 def evaluate_model(model, X_train, X_test, y_train, y_test):
#       3     model.fit(X_train, y_train)
# ----> 4     y_pred = model.predict(X_test)
#       5     print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
#       6     print(f'Classification Report:\n{classification_report(y_test, y_pred)}')
#
# ~\anaconda\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
# ...
